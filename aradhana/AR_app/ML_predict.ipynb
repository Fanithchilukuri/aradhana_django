# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Dataset

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# Display basic information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              92 non-null     int64
#  1   item_name       92 non-null     object
#  2   Wholesale_cost  92 non-null     float64
#  3   retail_cost     92 non-null     float64
#  4   profit          92 non-null     float64
#  5   code            92 non-null     object
#  6   season          92 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.2+ KB

# %% [markdown]
# Display summary statistics

# %%
print(data.describe())
# Out:
#              id  Wholesale_cost  retail_cost      profit
# count  92.00000       92.000000    92.000000   92.000000
# mean   46.50000       39.750000    91.391304   51.641304
# std    26.70206       21.368882    53.536053   32.375402
# min     1.00000        5.000000    15.000000   10.000000
# 25%    23.75000       25.000000    55.000000   30.000000
# 50%    46.50000       35.000000    80.000000   45.000000
# 75%    69.25000       50.000000   120.000000   70.000000
# max    92.00000      120.000000   300.000000  180.000000

# %% [markdown]
# Visualization: Distribution of Wholesale and Retail Costs

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Wholesale_cost'], kde=True, color='blue', label='Wholesale Cost')
sns.histplot(data['retail_cost'], kde=True, color='green', label='Retail Cost')
plt.title('Distribution of Wholesale and Retail Costs')
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Visualization: Profit vs Wholesale Cost

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Wholesale_cost', y='profit', data=data, hue='season')
plt.title('Profit vs Wholesale Cost by Season')
plt.xlabel('Wholesale Cost')
plt.ylabel('Profit')
plt.show()
